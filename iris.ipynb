# %% [markdown]
# **IMPORTING NECESSORY LIBRARIES**

# %%
import numpy as np
import pandas as pd
import statistics
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **IMPORTING THE DATASET FROM THE DESKTOP**

# %%
iris_data = pd.read_csv('Iris.csv')

# %% [markdown]
# **OVERVIEW OF A DATA**

# %%
# display the number of rows and columns
iris_data.shape
# Out:
# (150, 6)

# %% [markdown]
# **VISUALIZATION USING HISTOGRAM**

# %%
#Reading the data
data = pd.read_csv("Iris.csv")

#Bar chart with Species against SepalLength
plt. bar(data['Species'] , data['SepalLengthCm'])
plt.title("Distribution of Species based on Sepal Length")

#Setting the X and Y labels
plt. xlabel('Species types')
plt. ylabel('Sepal Length in cm')

#Adding the legends
plt.show()
